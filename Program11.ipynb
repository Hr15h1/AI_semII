# %% [markdown]
# Design and implement perceptrons, write your own code for learning (weight updating) task, for the AND, OR, NAND and NOR logic gates. Conduct experiments to evaluate the impact of bias on the perceptrons ability to learn and classify these logic gates accurately.

# %%
import numpy as np

# %%
class Perceptron:
    
    def __init__(self, learning_rate=0.01, iterations=300, no_of_features = 2):
        self.learning_rate = learning_rate
        self.iterations = iterations
        self.activation_function = self._activation_function
        self.weights = np.random.randn(no_of_features + 1) / np.sqrt(no_of_features)
        self.bias = None


    def fit(self, X, y):
        n_samples, n_features = X.shape
        self.bias = 0

        y_ = np.array([1 if i > 0 else 0 for i in y])

        for _ in range(self.iterations):
            for index, x_i in enumerate(X):
                linear_output = np.dot(x_i, self.weights) + self.bias
                y_predicted = self.activation_function(linear_output)

                update = self.learning_rate * (y_[index] - y_predicted)
                self.weights += update * x_i
                self.bias += update 


    def predict(self, X):
        linear_output = np.dot(X, self.weights) + self.bias
        y_predicted = self.activation_function(linear_output)
        return y_predicted


    def _activation_function(self, x):
        return np.where(x >= 0, 1, 0)

# %% [markdown]
# Training the Perceptron on OR gate

# %%
p1 = Perceptron(learning_rate=0.01, iterations = 30, no_of_features = 2)

X = np.array([[0, 0], 
              [0, 1],
              [1, 0],
              [1, 1]])
y_or = np.array([0, 1, 1, 1])
y_and = np.array([0, 0, 0, 1])
y_nand = np.array([1, 1, 1, 0])
y_nor = np.array([1, 0, 0, 0])

p1.fit(X, y_or)
print("OR Gate")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 12
#       9 y_nand = np.array([1, 1, 1, 0])
#      10 y_nor = np.array([1, 0, 0, 0])
# ---> 12 p1.fit(X, y_or)
#      13 print("OR Gate")
#
# Cell In[10], line 19, in Perceptron.fit(self, X, y)
#      17 for _ in range(self.iterations):
#      18     for index, x_i in enumerate(X):
# ---> 19         linear_output = np.dot(x_i, self.weights) + self.bias
#      20         y_predicted = self.activation_function(linear_output)
#      22         update = self.learning_rate * (y_[index] - y_predicted)
#
# ValueError: shapes (2,) and (3,) not aligned: 2 (dim 0) != 3 (dim 0)
